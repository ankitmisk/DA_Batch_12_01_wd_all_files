# %%
#  map
# 'insert
# apply
# 'to_csv', 'to_dict', 'to_excel',  'to_html', 'to_json'
# pd.datetiem

# %%
# Python:- 1
# DA:- 1.5
# Sql:- 30min
# 20hr

# %%
# 3 mon:- 
# 3 day:
# 3 hr
# 1 hr:

# %%
import pandas as pd

# %%
ate_series = pdd.date_range(start='01/01/2024',end='31/12/2024')

# %%
# AI:- Time series analysis:- stocks, sales, profit, covid

# %%
type(date_series)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
import numpy as np

# %%
y = np.random.randint(100,120,366)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(date_series[:20],y[:20])
plt.xticks(rotation = 90)
plt.show()

# %%
# from datetime import timedelta

# %%
date_series = pd.date_range(start='01/01/2024',end='31/03/2024',periods=3)
date_series
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-15', '2024-03-31'], dtype='datetime64[ns]', freq=None)

# %%
date_series = pd.date_range(start='01/01/2024',end='04/01/2024',freq='s')
date_series
# Out:
# DatetimeIndex(['2024-01-01 00:00:00', '2024-01-01 00:00:01',
#                '2024-01-01 00:00:02', '2024-01-01 00:00:03',
#                '2024-01-01 00:00:04', '2024-01-01 00:00:05',
#                '2024-01-01 00:00:06', '2024-01-01 00:00:07',
#                '2024-01-01 00:00:08', '2024-01-01 00:00:09',
#                ...
#                '2024-03-31 23:59:51', '2024-03-31 23:59:52',
#                '2024-03-31 23:59:53', '2024-03-31 23:59:54',
#                '2024-03-31 23:59:55', '2024-03-31 23:59:56',
#                '2024-03-31 23:59:57', '2024-03-31 23:59:58',
#                '2024-03-31 23:59:59', '2024-04-01 00:00:00'],
#               dtype='datetime64[ns]', length=7862401, freq='s')

# %%
date_series = pd.date_range(start='01/01/2024',end='02/01/2024',freq='s',tz = 'Asia/Tokyo')
date_series
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+09:00', '2024-01-01 00:00:01+09:00',
#                '2024-01-01 00:00:02+09:00', '2024-01-01 00:00:03+09:00',
#                '2024-01-01 00:00:04+09:00', '2024-01-01 00:00:05+09:00',
#                '2024-01-01 00:00:06+09:00', '2024-01-01 00:00:07+09:00',
#                '2024-01-01 00:00:08+09:00', '2024-01-01 00:00:09+09:00',
#                ...
#                '2024-01-31 23:59:51+09:00', '2024-01-31 23:59:52+09:00',
#                '2024-01-31 23:59:53+09:00', '2024-01-31 23:59:54+09:00',
#                '2024-01-31 23:59:55+09:00', '2024-01-31 23:59:56+09:00',
#                '2024-01-31 23:59:57+09:00', '2024-01-31 23:59:58+09:00',
#                '2024-01-31 23:59:59+09:00', '2024-02-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Tokyo]', length=2678401, freq='s')

# %%
date_series = pd.date_range(start='2024-09-09 11:38:10.768278',end='2024-09-09 11:38:10.768279',freq='ns',)
date_series
# Out:
# DatetimeIndex([   '2024-09-09 11:38:10.768278',
#                '2024-09-09 11:38:10.768278001',
#                '2024-09-09 11:38:10.768278002',
#                '2024-09-09 11:38:10.768278003',
#                '2024-09-09 11:38:10.768278004',
#                '2024-09-09 11:38:10.768278005',
#                '2024-09-09 11:38:10.768278006',
#                '2024-09-09 11:38:10.768278007',
#                '2024-09-09 11:38:10.768278008',
#                '2024-09-09 11:38:10.768278009',
#                ...
#                '2024-09-09 11:38:10.768278991',
#                '2024-09-09 11:38:10.768278992',
#                '2024-09-09 11:38:10.768278993',
#                '2024-09-09 11:38:10.768278994',
#                '2024-09-09 11:38:10.768278995',
#                '2024-09-09 11:38:10.768278996',
#                '2024-09-09 11:38:10.768278997',
#                '2024-09-09 11:38:10.768278998',
#                '2024-09-09 11:38:10.768278999',
# ...

# %%
from datetime import datetime,timedelta

# %%
print(datetime.now())
# Out:
# 2024-09-09 11:38:10.768278

# %%
print(datetime.now() + timedelta(2))
# Out:
# 2024-09-11 11:39:09.837667

# %%
# 'to_csv', 'to_dict', 'to_excel',  'to_html', 'to_json'

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df.to_csv('karan.csv',index=False)
print('done')
# Out:
# done

# %%
pd.read_csv('karan.csv')
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
path = r"C:\Users\Lenovo\Desktop\pandas\karan.csv"
df.to_csv(path,index =0)
print('done')
# Out:
# done

# %%
df.to_dict(orient='list')
# Out:
# {'col1': [1, 2], 'col2': [3, 4]}

# %%
df.to_dict(orient='records')
# Out:
# [{'col1': 1, 'col2': 3}, {'col1': 2, 'col2': 4}]

# %%
df.to_excel('filename.xlsx',index=False)# same as csv

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col1</th>
#       <th>col2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
adani = pd.read_csv(r"D:\All_Dataset_Xl_csv\adani.csv")

# %%
adani.to_html('adani.html')

# %%
adani.shape
# Out:
# (32806, 10)

# %%
adani.to_json('adani.json')

# %%
pd.read_json('adani.json')
# Out:
#                 timestamp      symbol  \
# 0     2002-06-30 18:30:00         ACC
# 1     2002-06-30 18:30:00   AMBUJACEM
# 2     2002-06-30 18:30:00    ADANIENT
# 3     2002-07-01 18:30:00   AMBUJACEM
# 4     2002-07-01 18:30:00         ACC
# ...                   ...         ...
# 32801 2023-09-05 18:30:00   AMBUJACEM
# 32802 2023-09-05 18:30:00  ADANIPORTS
# 32803 2023-09-05 18:30:00    ADANIENT
# 32804 2023-09-05 18:30:00        ATGL
# 32805 2023-09-05 18:30:00        NDTV
#
#                                              company      open      high  \
# 0                                        ACC Limited   106.697   108.697
# 1                             Ambuja Cements Limited    17.078    17.457
# 2                          Adani Enterprises Limited    -0.010    -0.011
# 3                             Ambuja Cements Limited    17.370    17.544
# 4                                        ACC Limited   107.397   108.931
# ...

# %%
# df.to_markdown()

# %%
adani.to_numpy()
# Out:
# array([[1025461800000000000, 'ACC', 'ACC Limited', ..., 659631, 0.0, 0.0],
#        [1025461800000000000, 'AMBUJACEM', 'Ambuja Cements Limited', ...,
#         630442, 0.0, 0.0],
#        [1025461800000000000, 'ADANIENT', 'Adani Enterprises Limited',
#         ..., 1080397, 0.0, 0.0],
#        ...,
#        [1693938600000000000, 'ADANIENT', 'Adani Enterprises Limited',
#         ..., 3640235, 0.0, 0.0],
#        [1693938600000000000, 'ATGL', 'Adani Total Gas Limited', ...,
#         228186, 0.0, 0.0],
#        [1693938600000000000, 'NDTV', 'New Delhi Television Limited', ...,
#         101881, 0.0, 0.0]], dtype=object)

# %%
df.to_xml('adani.xml')

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
# df.to_sql()

# %%
# file transfer
df.to_pickle('df.pkl')

# %%
import pickle

# %%
with open('df.pkl','rb') as f:
    loaded_df = pickle.load(f)

# %%
loaded_df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
pd.read_pickle('df.pkl')
# Out:
#    col1  col2
# 0     1     3
# 1     2     4
