# %%
# Pandas
# series
# how to create a series, list, array, dict, tuple
# naming, indexing
# mathematical op
# methods
import pandas as pd
pd.Series.abs
pd.Series.

# %%
import numpy as np

# %%
a = pd.Series(np.random.randint(1,100,10))

# %%
a[[3,4]] = np.nan

# %%
a[[1,5,8]] = np.nan

# %%
a
# Out:
# 0    75.0
# 1     NaN
# 2    37.0
# 3     NaN
# 4     NaN
# 5     NaN
# 6    95.0
# 7    82.0
# 8     NaN
# 9    27.0
# dtype: float64

# %%
a.backfill()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9992\2728290305.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   a.backfill()
# 0    75.0
# 1    37.0
# 2    37.0
# 3    95.0
# 4    95.0
# 5    95.0
# 6    95.0
# 7    82.0
# 8    27.0
# 9    27.0
# dtype: float64

# %%
a.bfill()
# Out:
# 0    75.0
# 1    37.0
# 2    37.0
# 3    95.0
# 4    95.0
# 5    95.0
# 6    95.0
# 7    82.0
# 8    27.0
# 9    27.0
# dtype: float64

# %%
a[0] = np.nan

# %%
a
# Out:
# 0     NaN
# 1     NaN
# 2    37.0
# 3     NaN
# 4     NaN
# 5     NaN
# 6    95.0
# 7    82.0
# 8     NaN
# 9    27.0
# dtype: float64

# %%
a.ffill()
# Out:
# 0     NaN
# 1     NaN
# 2    37.0
# 3    37.0
# 4    37.0
# 5    37.0
# 6    95.0
# 7    82.0
# 8    82.0
# 9    27.0
# dtype: float64

# %%
df = pd.DataFrame(np.random.randint(1,100,(5,5)))

# %%
df.iloc[1,4] = np.nan
df.iloc[2,3] = np.nan
df.iloc[1,2] = np.nan
df.iloc[2,4] = np.nan

# %%
df
# Out:
#     0   1     2     3     4
# 0  80  23  90.0  86.0  83.0
# 1  30  76   NaN   1.0   NaN
# 2  42  70  95.0   NaN   NaN
# 3  56  57  50.0  32.0  41.0
# 4  82  15  32.0  31.0  65.0

# %%
df.iloc[3,[1,2]] = np.nan

# %%
df
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0   NaN   1.0   NaN
# 2  42  70.0  95.0   NaN   NaN
# 3  56   NaN   NaN  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.fillna(0)
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0   0.0   1.0   0.0
# 2  42  70.0  95.0   0.0   0.0
# 3  56   0.0   0.0  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9992\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  90.0   1.0  83.0
# 2  42  70.0  95.0   1.0  83.0
# 3  56  70.0  95.0  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.ffill()
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  90.0   1.0  83.0
# 2  42  70.0  95.0   1.0  83.0
# 3  56  70.0  95.0  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0   NaN   1.0   NaN
# 2  42  70.0  95.0   NaN   NaN
# 3  56   NaN   NaN  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.interpolate()
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
import IPython

# %%
IPython.display.YouTubeVideo('vbWe5k4fFWE')

# %%
df.interpolate(method='polynomial',order = 2)
# Out:
#     0          1      2     3     4
# 0  80  23.000000   90.0  86.0  83.0
# 1  30  76.000000  101.0   1.0  50.0
# 2  42  70.000000   95.0   2.5  36.0
# 3  56  47.315789   72.0  32.0  41.0
# 4  82  15.000000   32.0  31.0  65.0

# %%
df.interpolate()

# %%
df1 = df.copy()

# %%
df1
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0   NaN   1.0   NaN
# 2  42  70.0  95.0   NaN   NaN
# 3  56   NaN   NaN  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.interpolate(inplace=True)

# %%
df
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df = df1.copy()

# %%
# 'forward', 'backward', 'both'
df.interpolate(limit_direction='forward')
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.interpolate(limit_direction='backward')
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.interpolate(limit_direction='both')
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.interpolate(limit_area='inside')
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0  92.5   1.0  69.0
# 2  42  70.0  95.0  16.5  55.0
# 3  56  42.5  63.5  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.fillna(0)
# Out:
#     0     1     2     3     4
# 0  80  23.0  90.0  86.0  83.0
# 1  30  76.0   0.0   1.0   0.0
# 2  42  70.0  95.0   0.0   0.0
# 3  56   0.0   0.0  32.0  41.0
# 4  82  15.0  32.0  31.0  65.0

# %%
df.fillna({1:df[1].mean(),
           2:df[2].mean()})
# Out:
#     0     1          2     3     4
# 0  80  23.0  90.000000  86.0  83.0
# 1  30  76.0  72.333333   1.0   NaN
# 2  42  70.0  95.000000   NaN   NaN
# 3  56  46.0  72.333333  32.0  41.0
# 4  82  15.0  32.000000  31.0  65.0

# %%
# df[1].mean()

# %%
for i in df.columns:
    df.fillna({i:df[i].mean()},inplace=True)

# %%
df
# Out:
#     0     1          2     3     4
# 0  80  23.0  90.000000  86.0  83.0
# 1  30  76.0  72.333333   1.0  63.0
# 2  42  70.0  95.000000  37.5  63.0
# 3  56  46.0  72.333333  32.0  41.0
# 4  82  15.0  32.000000  31.0  65.0

# %%
df[0].mode()
# Out:
# 0    30
# 1    42
# 2    56
# 3    80
# 4    82
# Name: 0, dtype: int32

# %%
ajay = pd.DataFrame({'A':[str(i) for i in [1,1,1,1,2,2,2,2,2,2,23,3,3,3,3]]})

# %%
ajay['A'].mode()
# Out:
# 0    2
# Name: A, dtype: object

# %%
# ajay['A'].mean()

# %%
ajay['A'].mode()[0]
# Out:
# '2'

# %%
pd.read_csv("C:\\Users\\Lenovo\\Desktop\\students_copy.csv")
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh    2354          Noida         DS
# 1        2   Ankush Sharma    3456  Greater Noida         DA
# 2        3    Yash Chauhan    4356          Delhi  FullStack
# 3        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
pd.read_csv("C:/Users/Lenovo/Desktop/students_copy.csv")
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh    2354          Noida         DS
# 1        2   Ankush Sharma    3456  Greater Noida         DA
# 2        3    Yash Chauhan    4356          Delhi  FullStack
# 3        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
path = r"C:\Users\Lenovo\Desktop\students_copy.csv"
pd.read_csv(path,)
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh    2354          Noida         DS
# 1        2   Ankush Sharma    3456  Greater Noida         DA
# 2        3    Yash Chauhan    4356          Delhi  FullStack
# 3        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
data = '''Name,Age,Sec,Salary
Arun,23,A,87654
Varun,25,B,87654
Karan,34,C,987654'''

# %%
print(data)
# Out:
# Name,Age,Sec,Salary
# Arun,23,A,87654
# Varun,25,B,87654
# Karan,34,C,987654

# %%
import csv

# %%
bytes(data,encoding = 'utf-8')
# Out:
# b'Name,Age,Sec,Salary\nArun,23,A,87654\nVarun,25,B,87654\nKaran,34,C,987654'

# %%
# pd.read_csv(bytes(data,encoding = 'utf-8'))

# %%
import csv

# %%
csv.StringIO(data)

# %%
import io

# %%
pd.read_csv(io.StringIO(data))
# Out:
#     Name  Age Sec  Salary
# 0   Arun   23   A   87654
# 1  Varun   25   B   87654
# 2  Karan   34   C  987654

# %%
print(data)
# Out:
# Name,Age,Sec,Salary
# Arun,23,A,87654
# Varun,25,B,87654
# Karan,34,C,987654

# %%
data = '''+------+---------+----------+--------+------------+
| id   | country | state    | amount | trans_date |
+------+---------+----------+--------+------------+
| 121  | US      | approved | 1000   | 2018-12-18 |
| 122  | US      | declined | 2000   | 2018-12-19 |
| 123  | US      | approved | 2000   | 2019-01-01 |
| 124  | DE      | approved | 2000   | 2019-01-07 |
+------+---------+----------+--------+------------+'''

# %%
print(data)
# Out:
# +------+---------+----------+--------+------------+
# | id   | country | state    | amount | trans_date |
# +------+---------+----------+--------+------------+
# | 121  | US      | approved | 1000   | 2018-12-18 |
# | 122  | US      | declined | 2000   | 2018-12-19 |
# | 123  | US      | approved | 2000   | 2019-01-01 |
# | 124  | DE      | approved | 2000   | 2019-01-07 |
# +------+---------+----------+--------+------------+

# %%
data = data.replace('+','').replace('-','').replace('|',',')

# %%
table = pd.read_csv(io.StringIO(data))
table = table.iloc[:,1:-1]
table
# Out:
#    id      country    state      amount   trans_date
# 0    121   US         approved      1000     20181218
# 1    122   US         declined      2000     20181219
# 2    123   US         approved      2000     20190101
# 3    124   DE         approved      2000     20190107

# %%
def convert_to_csv(data):
    data = data.replace('+','').replace('-','').replace('|',',')
    table = pd.read_csv(io.StringIO(data))
    table = table.iloc[:,1:-1]
    return table

# %%
data = '''+---------+------------+---------------+---------------+
| user_id | session_id | activity_date | activity_type |
+---------+------------+---------------+---------------+
| 1       | 1          | 2019-07-20    | open_session  |
| 1       | 1          | 2019-07-20    | scroll_down   |
| 1       | 1          | 2019-07-20    | end_session   |
| 2       | 4          | 2019-07-20    | open_session  |
| 2       | 4          | 2019-07-21    | send_message  |
| 2       | 4          | 2019-07-21    | end_session   |
| 3       | 2          | 2019-07-21    | open_session  |
| 3       | 2          | 2019-07-21    | send_message  |
| 3       | 2          | 2019-07-21    | end_session   |
| 4       | 3          | 2019-06-25    | open_session  |
| 4       | 3          | 2019-06-25    | end_session   |
+---------+------------+---------------+---------------+
'''

# %%
convert_to_csv(data)
# Out:
#     user_id   session_id   activity_date    activity_type
# 0          1            1        20190720   open_session
# 1          1            1        20190720   scroll_down
# 2          1            1        20190720   end_session
# 3          2            4        20190720   open_session
# 4          2            4        20190721   send_message
# 5          2            4        20190721   end_session
# 6          3            2        20190721   open_session
# 7          3            2        20190721   send_message
# 8          3            2        20190721   end_session
# 9          4            3        20190625   open_session
# 10         4            3        20190625   end_session

# %%
path
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\students_copy.csv'

# %%
pd.read_csv()

# %%
with open('C:\\Users\\Lenovo\\Desktop\\students_copy.csv') as f:
    data = f.read()
    data = data.replace(',','%')
    
with open('C:\\Users\\Lenovo\\Desktop\\students_copy.csv','w') as f:
    f.write(data)

# %%
path
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\students_copy.csv'

# %%
pd.read_csv(path,sep = '%')
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh    2354          Noida         DS
# 1        2   Ankush Sharma    3456  Greater Noida         DA
# 2        3    Yash Chauhan    4356          Delhi  FullStack
# 3        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
with open('C:\\Users\\Lenovo\\Desktop\\students_copy.csv') as f:
    data = f.read()
    data = data.replace('%',',')
    
with open('C:\\Users\\Lenovo\\Desktop\\students_copy.csv','w') as f:
    f.write(data)

# %%
pd.read_csv(path,header=[1,2])
# Out:
#    1    Sarwan Singh  2354         Noida         DS
#    2   Ankush Sharma  3456 Greater Noida         DA
# 0  3    Yash Chauhan  4356         Delhi  FullStack
# 1  4  Subigya Mishra  4657     Faridabad      AI/ML

# %%
pd.read_csv(path)
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh    2354          Noida         DS
# 1        2   Ankush Sharma    3456  Greater Noida         DA
# 2        3    Yash Chauhan    4356          Delhi  FullStack
# 3        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
pd.read_csv(path,names=['A','B','C','D','E'])
# Out:
#          A               B       C              D          E
# 0  Roll No            Name  Salary        Address     Course
# 1        1    Sarwan Singh    2354          Noida         DS
# 2        2   Ankush Sharma    3456  Greater Noida         DA
# 3        3    Yash Chauhan    4356          Delhi  FullStack
# 4        4  Subigya Mishra    4657      Faridabad      AI/ML

# %%
pd.read_csv(path,index_col=-1,header=1)
# Out:
#            1    Sarwan Singh  2354          Noida
# DS
# DA         2   Ankush Sharma  3456  Greater Noida
# FullStack  3    Yash Chauhan  4356          Delhi
# AI/ML      4  Subigya Mishra  4657      Faridabad

# %%
pd.read_csv(path,usecols=['Roll No','Salary'])
# Out:
#    Roll No  Salary
# 0        1    2354
# 1        2    3456
# 2        3    4356
# 3        4    4657

# %%
pd.read_csv(path,skiprows=[1,2])
# Out:
#    Roll No            Name  Salary    Address     Course
# 0        3    Yash Chauhan    4356      Delhi  FullStack
# 1        4  Subigya Mishra    4657  Faridabad      AI/ML

# %%
pd.read_csv(path,na_values='ola')
# Out:
#    Roll No            Name  Salary        Address     Course
# 0        1    Sarwan Singh  2354.0          Noida         DS
# 1        2   Ankush Sharma     NaN  Greater Noida         DA
# 2        3    Yash Chauhan  4356.0          Delhi  FullStack
# 3        4  Subigya Mishra  4657.0      Faridabad      AI/ML

# %%
# pd.read_csv(path,na_filter=)

# %%
for i in pd.read_csv(path,chunksize=1):
    print(i)
# Out:
#    Roll No          Name  Salary Address Course
# 0        1  Sarwan Singh    2354   Noida     DS
#    Roll No           Name Salary        Address Course
# 1        2  Ankush Sharma    ola  Greater Noida     DA
#    Roll No          Name  Salary Address     Course
# 2        3  Yash Chauhan    4356   Delhi  FullStack
#    Roll No            Name  Salary    Address Course
# 3        4  Subigya Mishra    4657  Faridabad  AI/ML

# %%
path = r"D:\All_Dataset_Xl_csv\adani.csv"

# %%
pd.read_csv(path)
# Out:
#                  timestamp      symbol  \
# 0      1025461800000000000         ACC
# 1      1025461800000000000   AMBUJACEM
# 2      1025461800000000000    ADANIENT
# 3      1025548200000000000   AMBUJACEM
# 4      1025548200000000000         ACC
# ...                    ...         ...
# 32801  1693938600000000000   AMBUJACEM
# 32802  1693938600000000000  ADANIPORTS
# 32803  1693938600000000000    ADANIENT
# 32804  1693938600000000000        ATGL
# 32805  1693938600000000000        NDTV
#
#                                              company      open      high  \
# 0                                        ACC Limited   106.697   108.697
# 1                             Ambuja Cements Limited    17.078    17.457
# 2                          Adani Enterprises Limited    -0.010    -0.011
# 3                             Ambuja Cements Limited    17.370    17.544
# 4                                        ACC Limited   107.397   108.931
# ...

# %%
big_file = pd.r

for i in pd.read_csv(path,chunksize=100):
    display(i)
# Out:
#               timestamp     symbol                    company     open  \
# 0   1025461800000000000        ACC                ACC Limited  106.697
# 1   1025461800000000000  AMBUJACEM     Ambuja Cements Limited   17.078
# 2   1025461800000000000   ADANIENT  Adani Enterprises Limited   -0.010
# 3   1025548200000000000  AMBUJACEM     Ambuja Cements Limited   17.370
# 4   1025548200000000000        ACC                ACC Limited  107.397
# ..                  ...        ...                        ...      ...
# 95  1029177000000000000        ACC                ACC Limited   92.693
# 96  1029263400000000000        ACC                ACC Limited   90.459
# 97  1029263400000000000   ADANIENT  Adani Enterprises Limited   -0.009
# 98  1029263400000000000  AMBUJACEM     Ambuja Cements Limited   14.068
# 99  1029349800000000000   ADANIENT  Adani Enterprises Limited   -0.009
#
#        high      low    close   volume  dividends  stock_splits
# ...

# %%
big_file = next(pd.read_csv(path,chunksize=100))

# %%
for i in pd.read_csv(path,chunksize=100):
    big_file = pd.concat([big_file,i])

# %%
big_file
# Out:
#                  timestamp      symbol  \
# 0      1025461800000000000         ACC
# 1      1025461800000000000   AMBUJACEM
# 2      1025461800000000000    ADANIENT
# 3      1025548200000000000   AMBUJACEM
# 4      1025548200000000000         ACC
# ...                    ...         ...
# 32801  1693938600000000000   AMBUJACEM
# 32802  1693938600000000000  ADANIPORTS
# 32803  1693938600000000000    ADANIENT
# 32804  1693938600000000000        ATGL
# 32805  1693938600000000000        NDTV
#
#                                              company      open      high  \
# 0                                        ACC Limited   106.697   108.697
# 1                             Ambuja Cements Limited    17.078    17.457
# 2                          Adani Enterprises Limited    -0.010    -0.011
# 3                             Ambuja Cements Limited    17.370    17.544
# 4                                        ACC Limited   107.397   108.931
# ...
