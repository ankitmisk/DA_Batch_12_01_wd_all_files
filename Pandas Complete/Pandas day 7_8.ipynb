# %%
import pandas as pd
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
ipl = pd.read_csv("D:\All_Dataset_Xl_csv\IPL Matches 2008-2020.csv")

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
ipl.sample()
# Out:
#          id     city        date player_of_match  \
# 386  598062  Chennai  2013-05-14        MS Dhoni
#
#                                venue  neutral_venue                team1  \
# 386  MA Chidambaram Stadium, Chepauk              0  Chennai Super Kings
#
#                 team2          toss_winner toss_decision               winner  \
# 386  Delhi Daredevils  Chennai Super Kings           bat  Chennai Super Kings
#
#     result  result_margin eliminator method        umpire1    umpire2
# 386   runs           33.0          N    NaN  C Shamshuddin  RJ Tucker

# %%
# missing values find

# %%
(ipl.isna().sum()/len(ipl))*100
# Out:
# id                  0.000000
# city                1.593137
# date                0.000000
# player_of_match     0.490196
# venue               0.000000
# neutral_venue       0.000000
# team1               0.000000
# team2               0.000000
# toss_winner         0.000000
# toss_decision       0.000000
# winner              0.490196
# result              0.490196
# result_margin       2.083333
# eliminator          0.490196
# method             97.671569
# umpire1             0.000000
# umpire2             0.000000
# dtype: float64

# %%
ipl.shape
# Out:
# (816, 17)

# %%
0.02*816
# Out:
# 16.32

# %%
ipl.shape
# Out:
# (816, 17)

# %%
ipl.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
ipl['method'].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
ipl_1 = ipl.fillna({'method':'fare_match'})

# %%
ipl_1.isna().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     4
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# method              0
# umpire1             0
# umpire2             0
# dtype: int64

# %%
ipl_1.isna().sum().sum()
# Out:
# 46

# %%
(46/816)*100
# Out:
# 5.637254901960785

# %%
ipl_2 = ipl_1.dropna()

# %%
ipl_2.isna().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
ipl_2['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Bengaluru', 'Sharjah', 'Dubai'],
#       dtype=object)

# %%
ipl_2.describe(include = 'object')
# Out:
#           city        date player_of_match         venue  \
# count      786         786             786           786
# unique      32         578             232            36
# top     Mumbai  2014-05-13  AB de Villiers  Eden Gardens
# freq       100           2              22            77
#
#                               team1           team2     toss_winner  \
# count                           786             786             786
# unique                           15              15              15
# top     Royal Challengers Bangalore  Mumbai Indians  Mumbai Indians
# freq                            101             101             100
#
#        toss_decision          winner   result eliminator      method  \
# count            786             786      786        786         786
# unique             2              15        2          1           2
# top            field  Mumbai Indians  wickets          N  fare_match
# ...

# %%
ipl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               786 non-null    int64
#  1   city             786 non-null    object
#  2   date             786 non-null    object
#  3   player_of_match  786 non-null    object
#  4   venue            786 non-null    object
#  5   neutral_venue    786 non-null    int64
#  6   team1            786 non-null    object
#  7   team2            786 non-null    object
#  8   toss_winner      786 non-null    object
#  9   toss_decision    786 non-null    object
#  10  winner           786 non-null    object
#  11  result           786 non-null    object
#  12  result_margin    786 non-null    float64
#  13  eliminator       786 non-null    object
#  14  method           786 non-null    object
#  15  umpire1          786 non-null    object
#  16  umpire2          786 non-null    object
# ...

# %%
# change data type

# %%
ipl_2['date'] = pd.to_datetime(ipl_2['date'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11844\211325225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipl_2['date'] = pd.to_datetime(ipl_2['date'])

# %%
ipl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 786 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               786 non-null    int64
#  1   city             786 non-null    object
#  2   date             786 non-null    datetime64[ns]
#  3   player_of_match  786 non-null    object
#  4   venue            786 non-null    object
#  5   neutral_venue    786 non-null    int64
#  6   team1            786 non-null    object
#  7   team2            786 non-null    object
#  8   toss_winner      786 non-null    object
#  9   toss_decision    786 non-null    object
#  10  winner           786 non-null    object
#  11  result           786 non-null    object
#  12  result_margin    786 non-null    float64
#  13  eliminator       786 non-null    object
#  14  method           786 non-null    object
#  15  umpire1          786 non-null    object
# ...

# %%
ipl_2.describe()
# Out:
#                  id                           date  neutral_venue  \
# count  7.860000e+02                            786     786.000000
# mean   7.538069e+05  2014-03-29 04:18:19.236641280       0.078880
# min    3.359820e+05            2008-04-18 00:00:00       0.000000
# 25%    5.012222e+05            2011-04-22 06:00:00       0.000000
# 50%    6.636760e+05            2013-11-04 12:00:00       0.000000
# 75%    1.082627e+06            2017-04-30 00:00:00       0.000000
# max    1.237181e+06            2020-11-10 00:00:00       1.000000
# std    3.078221e+05                            NaN       0.269724
#
#        result_margin
# count     786.000000
# mean       17.418575
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        20.000000
# max       146.000000
# std        22.120149

# %%
ipl_3 = ipl_2.replace({"Bengaluru":"Bangalore"})

# %%
ipl_3['city'].value_counts()
# Out:
# city
# Mumbai            100
# Kolkata            77
# Bangalore          76
# Delhi              72
# Hyderabad          63
# Chandigarh         56
# Chennai            56
# Jaipur             47
# Pune               38
# Abu Dhabi          27
# Dubai              23
# Durban             15
# Visakhapatnam      13
# Centurion          12
# Sharjah            12
# Ahmedabad          11
# Dharamsala          9
# Rajkot              9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Cape Town           6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
ipl_2['city'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
ipl_2['city'].value_counts().tail().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
ipl_3.shape[0]
# Out:
# 786

# %%
ipl.shape
# Out:
# (816, 17)

# %%
ipl_3.sample()
# Out:
#           id    city       date player_of_match                   venue  \
# 580  1082594  Indore 2017-04-08      GJ Maxwell  Holkar Cricket Stadium
#
#      neutral_venue            team1                   team2      toss_winner  \
# 580              0  Kings XI Punjab  Rising Pune Supergiant  Kings XI Punjab
#
#     toss_decision           winner   result  result_margin eliminator  \
# 580         field  Kings XI Punjab  wickets            6.0          N
#
#          method       umpire1        umpire2
# 580  fare_match  AK Chaudhary  C Shamshuddin

# %%
ipl_3['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Rajkot', 'Kanpur', 'Sharjah', 'Dubai'], dtype=object)

# %%
ipl_3['city'].nunique()
# Out:
# 31

# %%
ipl_3.sample()
# Out:
#           id       city       date player_of_match                 venue  \
# 770  1216506  Abu Dhabi 2020-11-01      RD Gaikwad  Sheikh Zayed Stadium
#
#      neutral_venue            team1                team2          toss_winner  \
# 770              0  Kings XI Punjab  Chennai Super Kings  Chennai Super Kings
#
#     toss_decision               winner   result  result_margin eliminator  \
# 770         field  Chennai Super Kings  wickets            9.0          N
#
#          method    umpire1    umpire2
# 770  fare_match  PG Pathak  VK Sharma

# %%
ipl_3['year'] = ipl_3['date'].dt.year
ipl_3['month'] = ipl_3['date'].dt.month

# %%
ipl_3.shape
# Out:
# (786, 19)

# %%
ipl_3.sample()
# Out:
#          id       city       date player_of_match            venue  \
# 112  392237  Centurion 2009-05-22    AC Gilchrist  SuperSport Park
#
#      neutral_venue             team1            team2      toss_winner  \
# 112              1  Delhi Daredevils  Deccan Chargers  Deccan Chargers
#
#     toss_decision           winner   result  result_margin eliminator  \
# 112         field  Deccan Chargers  wickets            6.0          N
#
#          method      umpire1    umpire2  year  month
# 112  fare_match  BR Doctrove  DJ Harper  2009      5

# %%
ipl_3['year'].describe()
# Out:
# count     786.000000
# mean     2013.884224
# std         3.684788
# min      2008.000000
# 25%      2011.000000
# 50%      2013.500000
# 75%      2017.000000
# max      2020.000000
# Name: year, dtype: float64

# %%
ipl_3['year'].nunique()
# Out:
# 13

# %%
ipl_3['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020])

# %%
ipl_3['year'].value_counts()
# Out:
# year
# 2012    74
# 2013    74
# 2011    72
# 2016    60
# 2018    60
# 2010    59
# 2008    58
# 2017    58
# 2019    57
# 2009    56
# 2015    56
# 2020    56
# 2014    46
# Name: count, dtype: int64

# %%
ipl_3['year'].value_counts().sort_index()
# Out:
# year
# 2008    58
# 2009    56
# 2010    59
# 2011    72
# 2012    74
# 2013    74
# 2014    46
# 2015    56
# 2016    60
# 2017    58
# 2018    60
# 2019    57
# 2020    56
# Name: count, dtype: int64

# %%
ipl_3['year'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='year'>

# %%
ipl_3['month'].value_counts().sort_index()
# Out:
# month
# 3      39
# 4     343
# 5     346
# 6       2
# 9      10
# 10     38
# 11      8
# Name: count, dtype: int64

# %%
ipl_3['month'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='month'>

# %%
ipl_3.sample()
# Out:
#         id            city       date player_of_match             venue  \
# 72  392197  Port Elizabeth 2009-04-27    SR Tendulkar  St George's Park
#
#     neutral_venue                  team1           team2     toss_winner  \
# 72              1  Kolkata Knight Riders  Mumbai Indians  Mumbai Indians
#
#    toss_decision          winner result  result_margin eliminator      method  \
# 72           bat  Mumbai Indians   runs           92.0          N  fare_match
#
#        umpire1    umpire2  year  month
# 72  BG Jerling  RB Tiffin  2009      4

# %%
ipl_3['player_of_match'].unique()
# Out:
# array(['BB McCullum', 'MEK Hussey', 'MF Maharoof', 'MV Boucher',
#        'DJ Hussey', 'SR Watson', 'V Sehwag', 'ML Hayden', 'YK Pathan',
#        'KC Sangakkara', 'JDP Oram', 'AC Gilchrist', 'SM Katich',
#        'MS Dhoni', 'ST Jayasuriya', 'GD McGrath', 'SE Marsh',
#        'SA Asnodkar', 'R Vinay Kumar', 'IK Pathan', 'SM Pollock',
#        'Sohail Tanvir', 'S Sreesanth', 'A Nehra', 'SC Ganguly',
#        'CRD Fernando', 'L Balaji', 'Shoaib Akhtar', 'A Mishra',
#        'DPMD Jayawardene', 'GC Smith', 'DJ Bravo', 'M Ntini',
#        'SP Goswami', 'A Kumble', 'KD Karthik', 'JA Morkel', 'P Kumar',
#        'Umar Gul', 'SK Raina', 'SR Tendulkar', 'R Dravid', 'DL Vettori',
#        'RP Singh', 'M Muralitharan', 'CH Gayle', 'AB de Villiers',
#        'RS Bopara', 'PP Ojha', 'TM Dilshan', 'HH Gibbs', 'DP Nannes',
#        'JP Duminy', 'Yuvraj Singh', 'SB Jakati', 'JH Kallis', 'G Gambhir',
#        'RG Sharma', 'A Singh', 'S Badrinath', 'DR Smith', 'LRPL Taylor',
# ...

# %%
ipl_3['player_of_match'].nunique()
# Out:
# 232

# %%
player_match = ','.join(ipl_3['player_of_match'].unique()).lower().split(',')

# %%
len(player_match)
# Out:
# 232

# %%
ipl_3['player_of_match'].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    22
# CH Gayle          22
# RG Sharma         18
# MS Dhoni          17
# DA Warner         17
# SR Watson         16
# YK Pathan         15
# SK Raina          14
# G Gambhir         13
# V Kohli           12
# Name: count, dtype: int64

# %%
ipl_3['player_of_match'].value_counts().head(10).plot.pie(autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#

# %%
ipl_3
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
print(dir(pd.DataFrame))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %%
print(dir(pd.Series))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__r
# ...

# %%
# read_csv

ipl_3['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
ipl_3['venue'].nunique()
# Out:
# 36

# %%
len(set(ipl_3['venue']))
# Out:
# 36

# %%
ipl_3['venue'].str.lower().nunique()
# Out:
# 36

# %%
ipl_3['venue'].value_counts().head(10)
# Out:
# venue
# Eden Gardens                                  77
# Feroz Shah Kotla                              72
# Wankhede Stadium                              72
# Rajiv Gandhi International Stadium, Uppal     63
# M Chinnaswamy Stadium                         62
# MA Chidambaram Stadium, Chepauk               56
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Sheikh Zayed Stadium                          27
# Dubai International Cricket Stadium           23
# Name: count, dtype: int64

# %%
ipl_3['venue'].value_counts().tail(10)
# Out:
# venue
# Barabati Stadium                                    7
# St George's Park                                    7
# Shaheed Veer Narayan Singh International Stadium    6
# Newlands                                            6
# Nehru Stadium                                       5
# Green Park                                          4
# Vidarbha Cricket Association Stadium, Jamtha        3
# De Beers Diamond Oval                               3
# Buffalo Park                                        3
# OUTsurance Oval                                     2
# Name: count, dtype: int64

# %%
ipl_3['neutral_venue'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ipl_3.sample()
# Out:
#          id        city       date player_of_match  \
# 273  548331  Chandigarh 2012-04-20        CH Gayle
#
#                                           venue  neutral_venue  \
# 273  Punjab Cricket Association Stadium, Mohali              0
#
#                team1                        team2  \
# 273  Kings XI Punjab  Royal Challengers Bangalore
#
#                      toss_winner toss_decision                       winner  \
# 273  Royal Challengers Bangalore         field  Royal Challengers Bangalore
#
#       result  result_margin eliminator      method umpire1    umpire2  year  \
# 273  wickets            5.0          N  fare_match  S Ravi  RJ Tucker  2012
#
#      month
# 273      4

# %%
ipl_3[ipl_3['neutral_venue'] == 1]
# Out:
#          id            city       date player_of_match                 venue  \
# 58   392181       Cape Town 2009-04-18    SR Tendulkar              Newlands
# 59   392182       Cape Town 2009-04-18        R Dravid              Newlands
# 60   392183       Cape Town 2009-04-19      DL Vettori              Newlands
# 61   392184       Cape Town 2009-04-19        RP Singh              Newlands
# 62   392185  Port Elizabeth 2009-04-20  M Muralitharan      St George's Park
# ..      ...             ...        ...             ...                   ...
# 400  729283       Abu Dhabi 2014-04-18      GJ Maxwell  Sheikh Zayed Stadium
# 401  729285       Abu Dhabi 2014-04-18       AM Rahane  Sheikh Zayed Stadium
# 405  729293       Abu Dhabi 2014-04-21        SK Raina  Sheikh Zayed Stadium
# 411  729305       Abu Dhabi 2014-04-26        PV Tambe  Sheikh Zayed Stadium
# 412  729307       Abu Dhabi 2014-04-26  Sandeep Sharma  Sheikh Zayed Stadium
#
# ...

# %%
ipl_3[ipl_3['neutral_venue'] == 0]
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_3['team1'].nunique()
# Out:
# 15

# %%
len(set(ipl_3['team1']))
# Out:
# 15

# %%
ipl_3['team1'].str.lower().nunique()
# Out:
# 15

# %%
ipl_3['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    101
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Delhi Daredevils                80
# Rajasthan Royals                67
# Sunrisers Hyderabad             56
# Deccan Chargers                 39
# Pune Warriors                   23
# Delhi Capitals                  17
# Gujarat Lions                   15
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: count, dtype: int64

# %%
ipl_4 = ipl_3.replace({'Delhi Daredevils':'Delhi Capitals',
               
              'Rising Pune Supergiants':'Rising Pune Supergiant',
               
               'Deccan Chargers':'Sunrisers Hyderabad'})

# %%
ipl_4['team1'].value_counts().sum()
# Out:
# 786

# %%
ipl_4.shape[0]
# Out:
# 786

# %%
ipl_4['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    101
# Delhi Capitals                  97
# Sunrisers Hyderabad             95
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Rajasthan Royals                67
# Pune Warriors                   23
# Gujarat Lions                   15
# Rising Pune Supergiant          14
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl_4.groupby('team1')['id'].count().sort_values(ascending = False)
# Out:
# team1
# Royal Challengers Bangalore    101
# Delhi Capitals                  97
# Sunrisers Hyderabad             95
# Mumbai Indians                  94
# Chennai Super Kings             92
# Kolkata Knight Riders           91
# Kings XI Punjab                 90
# Rajasthan Royals                67
# Pune Warriors                   23
# Gujarat Lions                   15
# Rising Pune Supergiant          14
# Kochi Tuskers Kerala             7
# Name: id, dtype: int64

# %%
# data analysis:- domain knowledge

# %%
# bp:- 500

# %%
ipl_4['team2'].value_counts().sort_index()
# Out:
# team2
# Chennai Super Kings             82
# Delhi Capitals                  88
# Gujarat Lions                   14
# Kings XI Punjab                 93
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           95
# Mumbai Indians                 101
# Pune Warriors                   22
# Rajasthan Royals                87
# Rising Pune Supergiant          16
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             97
# Name: count, dtype: int64

# %%
ipl_4['team1'].value_counts().sort_index()
# Out:
# team1
# Chennai Super Kings             92
# Delhi Capitals                  97
# Gujarat Lions                   15
# Kings XI Punjab                 90
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           91
# Mumbai Indians                  94
# Pune Warriors                   23
# Rajasthan Royals                67
# Rising Pune Supergiant          14
# Royal Challengers Bangalore    101
# Sunrisers Hyderabad             95
# Name: count, dtype: int64

# %%
(ipl_4['team1'].value_counts().sort_index() + ipl_4['team2'].value_counts().sort_index()).sort_values(ascending = False)
# Out:
# team1
# Mumbai Indians                 195
# Sunrisers Hyderabad            192
# Kolkata Knight Riders          186
# Delhi Capitals                 185
# Royal Challengers Bangalore    185
# Kings XI Punjab                183
# Chennai Super Kings            174
# Rajasthan Royals               154
# Pune Warriors                   45
# Rising Pune Supergiant          30
# Gujarat Lions                   29
# Kochi Tuskers Kerala            14
# Name: count, dtype: int64

# %%
(ipl_4['team1'].value_counts().sort_index() + ipl_4['team2'].value_counts().sort_index()).sort_values(ascending = False).sum()
# Out:
# 1572

# %%
786*2
# Out:
# 1572

# %%
ipl_4['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 118
# Chennai Super Kings            103
# Kolkata Knight Riders           97
# Sunrisers Hyderabad             92
# Royal Challengers Bangalore     87
# Delhi Capitals                  82
# Kings XI Punjab                 82
# Rajasthan Royals                79
# Rising Pune Supergiant          15
# Gujarat Lions                   13
# Pune Warriors                   12
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
ipl_4
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 810  1216546       Dubai 2020-10-20        S Dhawan
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ipl_4.groupby('year').last()
# Out:
#            id          city       date player_of_match  \
# year
# 2008   336040        Mumbai 2008-06-01       YK Pathan
# 2009   392239  Johannesburg 2009-05-24        A Kumble
# 2010   419165        Mumbai 2010-04-25        SK Raina
# 2011   501271       Chennai 2011-05-28         M Vijay
# 2012   548381       Chennai 2012-05-27        MS Bisla
# 2013   598073       Kolkata 2013-05-26      KA Pollard
# 2014   734049     Bangalore 2014-06-01       MK Pandey
# 2015   829823       Kolkata 2015-05-24       RG Sharma
# 2016   981019     Bangalore 2016-05-29     BCJ Cutting
# 2017  1082650     Hyderabad 2017-05-21       KH Pandya
# 2018  1136620        Mumbai 2018-05-27       SR Watson
# 2019  1181768     Hyderabad 2019-05-12       JJ Bumrah
# 2020  1237181         Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# year
# 2008                 Dr DY Patil Sports Academy              0
# ...

# %%
ipl_4[ipl_4['year'] == 2019]
# Out:
#           id           city       date  player_of_match  \
# 696  1175356        Chennai 2019-03-23  Harbhajan Singh
# 697  1175357        Kolkata 2019-03-24       AD Russell
# 698  1175358         Mumbai 2019-03-24          RR Pant
# 699  1175359         Jaipur 2019-03-25         CH Gayle
# 700  1175360          Delhi 2019-03-26        SR Watson
# 701  1175361        Kolkata 2019-03-27       AD Russell
# 702  1175362      Bangalore 2019-03-28        JJ Bumrah
# 703  1175363      Hyderabad 2019-03-29      Rashid Khan
# 704  1175364     Chandigarh 2019-03-30       MA Agarwal
# 706  1175366      Hyderabad 2019-03-31      JM Bairstow
# 707  1175367        Chennai 2019-03-31         MS Dhoni
# 708  1175368     Chandigarh 2019-04-01        SM Curran
# 709  1175369         Jaipur 2019-04-02          S Gopal
# 710  1175370         Mumbai 2019-04-03        HH Pandya
# 711  1175371          Delhi 2019-04-04      JM Bairstow
# 712  1175372      Bangalore 2019-04-05       AD Russell
# ...

# %%
ipl_4.groupby('year').last()['winner'].value_counts()
# Out:
# winner
# Mumbai Indians           5
# Chennai Super Kings      3
# Sunrisers Hyderabad      2
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Name: count, dtype: int64

# %%
ipl_4.groupby(['toss_winner','toss_decision'])['winner']

# %%
ipl_4['toss_decision'].value_counts()
# Out:
# toss_decision
# field    477
# bat      309
# Name: count, dtype: int64

# %%
ipl_4.groupby('toss_decision')['winner'].value_counts()
# Out:
# toss_decision  winner
# bat            Chennai Super Kings            53
#                Mumbai Indians                 48
#                Kolkata Knight Riders          38
#                Rajasthan Royals               36
#                Sunrisers Hyderabad            35
#                Delhi Capitals                 32
#                Royal Challengers Bangalore    31
#                Kings XI Punjab                23
#                Pune Warriors                   9
#                Gujarat Lions                   2
#                Rising Pune Supergiant          2
# field          Mumbai Indians                 70
#                Kings XI Punjab                59
#                Kolkata Knight Riders          59
#                Sunrisers Hyderabad            57
#                Royal Challengers Bangalore    56
#                Chennai Super Kings            50
#                Delhi Capitals                 50
#                Rajasthan Royals               43
# ...
